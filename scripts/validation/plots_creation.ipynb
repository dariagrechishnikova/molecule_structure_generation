# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
from pathlib import Path

#mpl.style.use('seaborn-pastel')
#sc=["pale red","dusty purple","denim blue"]
sc=["scarlet","warm purple","azul"]
sns.set_palette(sns.xkcd_palette(sc))



def show_hist(list_to_show_gen,list_to_gen_1000, list_to_show_train,plot_title,ds_num, axis_name):
  plt.figure()
  a4_dims = (6, 4)
  fig, ax = plt.subplots(figsize=a4_dims)
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.6}
  sns.distplot( list_to_show_gen ,  label="Generated (1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_show_train ,  label="Train", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_gen_1000 ,  label="Generated (10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  plt.legend(loc='upper right')
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  plt.savefig(f'{plot_title}_{ds_num}.png')
  return


def show_hist_qed(list_to_show_gen,list_to_gen_1000, list_to_show_train,plot_title,ds_num, axis_name):
  plt.figure()
  a4_dims = (6, 4)
  fig, ax = plt.subplots(figsize=a4_dims)
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.6}
  sns.distplot( list_to_show_gen ,  label="Generated\n(1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_show_train ,  label="Train", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_gen_1000 ,  label="Generated\n(10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  plt.legend(loc='upper right')
  plt.xlim(0, 1.3)
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  plt.savefig(f'{plot_title}_{ds_num}.png')
  return


def show_hist_logp(list_to_show_gen,list_to_gen_1000, list_to_show_train,plot_title,ds_num, axis_name):
  plt.figure()
  a4_dims = (6, 4)
  fig, ax = plt.subplots(figsize=a4_dims)
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.6}
  sns.distplot( list_to_show_gen ,  label="Generated (1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_show_train ,  label="Train", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_gen_1000 ,  label="Generated (10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  plt.legend(loc='upper right')
  plt.xlim(-8, 18)
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  plt.savefig(f'{plot_title}_{ds_num}.png')
  return
  
  
  
  


def read_data_by_name(name, model_id):
  path_to_your_folder_with_data = Path(r'')
  data_filenames = [path_to_your_folder_with_data / f'{name}_{model_id}_{i}.txt' for i in range(3)]
  arrays = [np.loadtxt(filename) for filename in data_filenames]
  return arrays


                                                                                                                                                
plot_names = ['h_accept', 'h_donor', 'len', 'mol_weight', 'rot_bond', 'tpsa', 'sas']
axis_names = ['number of H acceptors', 'number of H donors', 'length', 'molecular weight', 'rotatable bonds', 'tpsa', 'sas']
#plot_names = ['qed', 'logP']
i=0
for name in plot_names:
    for model_id in range(1, 2):
      data = read_data_by_name(name, model_id)
      for d in data:
        print(len(d))
        
      show_hist(*data, name, model_id, axis_names[i])
    i=i+1
      
      
      

      
model_id = 1
name = 'qed'
data = read_data_by_name(name, model_id)
for d in data:
  print(len(d))

show_hist_qed(*data, name, model_id,'QED')




model_id = 1
name = 'logP'
data = read_data_by_name(name, model_id)
for d in data:
  print(len(d))

show_hist_logp(*data, name, model_id, 'logP')

# %%
from google.colab import files


plot_names = ['h_accept', 'h_donor', 'len', 'logP', 'mol_weight', 'qed', 'rot_bond', 'tpsa','sas']
for name in plot_names:
  files.download(name+'_1.png')

# %%
#tanimoto


sc=["scarlet","azul"]
sns.set_palette(sns.xkcd_palette(sc))


plt.rcParams.update({'font.size': 8})




def show_hist_tanimoto(list_to_show_gen,list_to_gen_1000,plot_title,ds_num, axis_name):
  plt.figure()
  a4_dims = (6, 4)
  fig, ax = plt.subplots(figsize=a4_dims)
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.5}
  sns.distplot( list_to_show_gen ,  label="Generated (1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_gen_1000 ,  label="Generated (10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  plt.legend(loc='upper right')
  plt.xlim(0.25, 1.05)
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  plt.savefig('tanimoto.png',dpi=300)
  return



list_to_show_gen = np.loadtxt('generated_1.txt')
list_to_gen_1000 = np.loadtxt('generated_1000_1.txt')


show_hist_tanimoto(list_to_show_gen,list_to_gen_1000,'tanimoto',1, 'Tanimoto similarity')

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
from pathlib import Path

plt.rcParams.update({'font.size': 16})

#mpl.style.use('seaborn-pastel')
#sc=["pale red","dusty purple","denim blue"]
sc=["scarlet","warm purple","azul"]
sns.set_palette(sns.xkcd_palette(sc))



def show_hist(list_to_show_gen,list_to_gen_1000, list_to_show_train,plot_title,ds_num, axis_name):
  #plt.figure()
  #a4_dims = (6, 4)
  #fig, ax = plt.subplots(2,2)
  
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.5}
  sns.distplot( list_to_show_gen ,  label="Generated (1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_show_train ,  label="Train", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_gen_1000 ,  label="Generated (10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  #plt.legend(loc='upper right')
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  #plt.savefig(f'{plot_title}_{ds_num}.png')
  return


def show_hist_qed(list_to_show_gen,list_to_gen_1000, list_to_show_train,plot_title,ds_num, axis_name):
  #plt.figure()
  a4_dims = (6, 4)
  #fig, ax = plt.subplots(figsize=a4_dims)
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.6}
  sns.distplot( list_to_show_gen ,  label="Generated\n(1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_show_train ,  label="Train", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_gen_1000 ,  label="Generated\n(10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  #plt.legend(loc='upper right')
  plt.xlim(0, 1.3)
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  #plt.savefig(f'{plot_title}_{ds_num}.png')
  return


def show_hist_logp(list_to_show_gen,list_to_gen_1000, list_to_show_train,plot_title,ds_num, axis_name):
  #plt.figure()
  a4_dims = (6, 4)
  #fig, ax = plt.subplots(figsize=a4_dims)
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.6}
  sns.distplot( list_to_show_gen ,  label="Generated (1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_show_train ,  label="Train", hist_kws=hist_options, kde=False, norm_hist=True)
  sns.distplot( list_to_gen_1000 ,  label="Generated (10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  #plt.legend(loc='upper right')
  plt.xlim(-8, 18)
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  #plt.savefig(f'{plot_title}_{ds_num}.png')
  return
  
  
  
  


def read_data_by_name(name, model_id):
  path_to_your_folder_with_data = Path(r'')
  data_filenames = [path_to_your_folder_with_data / f'{name}_{model_id}_{i}.txt' for i in range(3)]
  arrays = [np.loadtxt(filename) for filename in data_filenames]
  return arrays


                                                                                                                                                
plot_names = ['h_accept', 'h_donor', 'len', 'mol_weight', 'rot_bond', 'tpsa', 'sas', 'qed', 'logP']
axis_names = ['Number of H acceptors', 'Number of H donors', 'Length', 'Molecular weight (Da)', 'Number of rotatable bonds', 'TPSA (Å^2)', 'SAS']
plot_label = ['a','b','c','d','e','f','g','h','i']
#plot_names = ['qed', 'logP']


fig=plt.figure(figsize=(16,12))  


i=0
for name in plot_names:
    for model_id in range(1, 2):
      data = read_data_by_name(name, model_id)
      #for d in data:
        #print(len(d))
      
      fig.tight_layout()
      ax = fig.add_subplot(3,3,i+1) 
      if name == 'qed':
        show_hist_qed(*data, name, model_id,'QED')
      elif name == 'logP':
        show_hist_logp(*data, name, model_id, 'LogP')
      else:
        show_hist(*data, name, model_id, axis_names[i])


      #show_hist(*data, name, model_id, axis_names[i])
    i=i+1
      
      
      


handles, labels = ax.get_legend_handles_labels()
#fig.legend(handles, labels, loc='lower center')
fig.legend( handles, labels, loc = (0.25, 0), ncol=3, frameon=False, borderpad=0 ) 
#plt.show()
#fig.legend( handles, labels, bbox_to_anchor=(0., -0.5, 0.5, 0.5) prop={'size': 16} )
#fig.savefig('physchem_panel.svg', format='svg')
fig.savefig('physchem_panel.png',dpi=300)

# %%
#tanimoto separate


sc=["scarlet","azul"]
sns.set_palette(sns.xkcd_palette(sc))



def show_hist_tanimoto1(list_to_show_gen,ds_num, axis_name):
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.6}
  sns.distplot( list_to_show_gen ,  label="Generated (1 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  #plt.legend(loc='upper right')
  plt.xlim(0.25, 1.05)
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  #plt.savefig(f'{plot_title}_{ds_num}.png')
  return

def show_hist_tanimoto10(list_to_gen_1000,ds_num, axis_name):
  hist_options = {'histtype': 'stepfilled', 'ec': 'k','alpha': 0.6}
  sns.distplot( list_to_gen_1000 ,  label="Generated (10 per 1)", hist_kws=hist_options, kde=False, norm_hist=True)
  #plt.legend(loc='upper right')
  plt.xlim(0.25, 1.05)
  #plt.title(plot_title+str(ds_num))
  #plt.show()
  plt.xlabel(axis_name)
  #plt.savefig(f'{plot_title}_{ds_num}.png')
  return




plot_labels = ['a','b']
#plot_names = ['qed', 'logP']


fig=plt.figure(figsize=(7,5))  

list_to_show_gen = np.loadtxt('generated_1.txt')
list_to_gen_1000 = np.loadtxt('generated_1000_1.txt')
i=0
for l in plot_labels:
      fig.tight_layout()
      ax = fig.add_subplot(1,2,i+1) 
      ax.text(-0.1, 1.15, l)
      if l == 'a':
        show_hist_tanimoto1(list_to_show_gen,  model_id,'Tanomoto similarity to the nearest neighbor')
      elif l == 'b':
        show_hist_tanimoto10(list_to_gen_1000,  model_id, 'Tanomoto similarity to the nearest neighbor')


      #show_hist(*data, name, model_id, axis_names[i])
      i=i+1





show_hist_tanimoto(list_to_show_gen,list_to_gen_1000,'tanimoto',1, 'Tanomoto similarity to the nearest neighbor')

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import matplotlib.patches as mpatches
import numpy as np


plt.rcParams.update({'font.size': 14})

names = ['Androgen receptor','Leukotriene A-4 hydrolase','Neutrophil collagenase','Cytochrome P450 3A4','Egl nine homolog 1','Chymase','Peptidyl-prolyl cis-trans isomerase FKBP1A','Gamma-butyrobetaine dioxygenase','AP2-associated protein kinase 1','Death-associated protein kinase 3','Galectin-3','Tyrosine-protein phosphatase non-receptor type 6']
means_gen = [-6.144444444444444, -9.77, -10.0375, -10.4, -8.283333333333333, -9.41, -7.76, -6.92, -8.29, -9.07, -7.15, -10.66]
stds_gen = [0.9900741959975761, 0.41964270516714597, 0.5977823600609172, 0.6693280212272604, 0.40173235977313176, 0.8814193099768124, 0.6437390775772434, 1.5657586020839869, 0.16401219466856728, 0.7707788269017252, 0.32015621187164234, 0.49436828377233094]
means_database = [-6.9799999999999995, -10.98, -9.430000000000001, -9.999999999999998, -8.879999999999999, -8.889999999999999, -7.216666666666666, -5.6, -8.785714285714285, -8.91111111111111, -7.2700000000000005, -9.95]
stds_database = [1.5203946855997623, 0.8623224454924042, 1.0354226190305096, 0.7375635565834312, 0.7025667228100119, 0.6007495318350236, 0.6361778227997438, 0.0, 1.0301575072754257, 1.085709644471654, 1.0325211862233141, 0.6499999999999995]
def swap_columns(data, left, right):
    new_data = np.copy(data)
    new_data[:, left] = data[:, right]
    new_data[:, right] = data[:, left]
    return new_data

def normalize_color(color):
    r, g, b, a = color
    f = 1/255
    return r*f, g*f, b*f, a*f

def remove_alpha(color):
    r, g, b, _ = color
    return r, g, b, 1

class PointWithSdObject(object):
    def __init__(self, color):
        self.color = color

class PointWithSdObjectHandler(object):
    def __init__(self, color):
        self.color = color

    def legend_artist(self, legend, orig_handle, fontsize, handlebox):
        x0, y0 = handlebox.xdescent, handlebox.ydescent
        width, height = handlebox.width, handlebox.height
        xc, yc = x0 + width/2, y0 + height/2
        line_width = width / 12
        patch = mpatches.Rectangle([x0, y0], width, height, facecolor=self.color)
        patch_line = mpatches.Rectangle([xc - line_width/2, y0], line_width, height, facecolor=remove_alpha(self.color))
        handlebox.add_artist(patch)
        handlebox.add_artist(patch_line)
        return patch


figsize = 7  # inches
fig_dpi = 300
plot_height_ratio = 0.6

mg = np.array(means_gen)
md = np.array(means_database)

sg = np.array(stds_gen)
sd = np.array(stds_database)

initial_diffs = mg - md  # generated - database, if positive -> generated is worse

sorted_indices = np.argsort(mg)
combined = np.vstack((mg, md))

sorted_combined = combined[:, sorted_indices]
#sorted_combined = swap_columns(sorted_combined, 8, 9)
#sorted_combined = swap_columns(sorted_combined, 4, 5)
#sorted_combined = swap_columns(sorted_combined, 0, 2)

#sorted_combined = combined

#print(combined)

diffs = sorted_combined[0] - sorted_combined[1]
red = normalize_color((237, 28, 36, 60))
green = normalize_color((34, 177, 76, 60))

database_color = normalize_color((63, 72, 204, 60))
generated_color= normalize_color((255, 127, 39, 60))

colors = [red if d > 0 else green for d in diffs]
column_width = 0.8
half_width = column_width / 2
linewidth = 2

plot_width_ratio = 0.6
fig = plt.figure(figsize=(figsize / plot_width_ratio, figsize), dpi=fig_dpi)
ax = fig.add_subplot(111)

box = ax.get_position()
ax.set_position([box.x1 - box.width * plot_width_ratio, box.y0, box.width * plot_width_ratio, box.height])

#plt.fill_between(xs, sorted_combined[0], sorted_combined[1], step='mid', color=colors)
for i in range(len(names)):
    cur_y_range = [i-half_width, i+half_width]
    ystart, yend = cur_y_range

    ax.fill_betweenx(cur_y_range, sorted_combined[0, i] - sg[i]/2, sorted_combined[0, i] + sg[i]/2, color=generated_color)
    ax.fill_betweenx(cur_y_range, sorted_combined[1, i] - sd[i]/2, sorted_combined[1, i] + sd[i]/2, color=database_color)

    #ax.fill_betweenx(cur_y_range, sorted_combined[0, i], sorted_combined[1, i], color=colors[i])
    ax.vlines(sorted_combined[0, i], ystart, yend, color=remove_alpha(generated_color), linewidth=linewidth)
    ax.vlines(sorted_combined[1, i], ystart, yend, color=remove_alpha(database_color), linewidth=linewidth)

xs = np.arange(-0.5, 11.5, 1.0)
#plt.step(xs, sorted_combined[0], where='post', color='b', linewidth=3)
#plt.step(xs, sorted_combined[1], where='post', color='k', linewidth=3)

sorted_names = [names[i] for i in sorted_indices]

plt.yticks(range(len(names)), sorted_names, rotation=0)
#plt.title("Generated proteins vs database proteins")
plt.grid()
plt.xlabel("Energy (kcal/mol)")
#plt.legend()

legend_labels = ['Generated', 'Database']
legend_colors = [generated_color, database_color]
#legend_patches = [mpatches.Patch(color=legend_colors[i], label=legend_labels[i])
                  #for i in range(len(legend_colors))]
legend_patches = [PointWithSdObject(generated_color), PointWithSdObject(database_color)]
#plt.legend(legend_patches, legend_labels, loc='lower right',
           #handler_map={patch: PointWithSdObjectHandler(patch.color) for patch in legend_patches},
           #prop={'size': 14})


plt.legend(legend_patches, legend_labels, loc='lower right',
           handler_map={patch: PointWithSdObjectHandler(patch.color) for patch in legend_patches})

#plt.show()
plt.savefig(rf'figure1.png', dpi=fig_dpi)
